# %% [markdown]
# # 1. Importing libraries and datasets

# %% [markdown]
# ## 1.1 Importing torch

# %%
model_name = "bert-base-multilingual-cased"

# %%
import torch
# check if we have cuda installed
if torch.cuda.is_available():
    # to use GPU
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('GPU is:', torch.cuda.get_device_name(0))
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# No GPU available, using the CPU instead.

# %% [markdown]
# ## 1.2 Importing language detection
#
# - For Malay, we use dictionaries from IPA-Dict and Dewan Bahasa.
# - For English, we use NLTK corpus.

# %%
import json
import nltk

# my_raw1 = json.load(open('../dictionary/200k-english-malay.json'))
# my_raw2 = open('../dictionary/en-ms.txt', encoding="utf8")
# my_raw3 = open('../dictionary/malay-ipa-dict.txt', encoding="utf8")

# my_raw1 = [x[1] for x in my_raw1]
# my_raw2 = [x.split('\t')[1].strip() for x in my_raw2.readlines()]
# my_raw3 = [x.split('\t')[0] for x in my_raw3.readlines()]

# with open('../dictionary/combined-malay-dict.txt', 'w', encoding="utf8") as fp:
#     for item in sorted(list(dict.fromkeys(my_raw1 + my_raw2 + my_raw3))):
#         if item:
#             fp.write("%s\n" % item)

with open('../dictionary/combined-malay-dict.txt', encoding="utf8") as fp:
    malay_dict = set([x.strip() for x in fp.readlines()])
    
eng_dict = set(nltk.corpus.words.words())
    
def detect_malay(text): return text in malay_dict
def detect_english(text): return text in eng_dict

# %% [markdown]
# ## 1.3 Importing and combining datasets

# %%
# # install pandas
# !pip install pandas

import pandas as pd
combined_df = pd.DataFrame()

# local-new: text + label*
df = pd.read_csv(r'../data/malaya/local-news.csv')
combined_df = pd.concat([combined_df, df[['text', 'label']].rename(columns={'label': 'sentiment'})])

# semisupervised-bert-xlnet: text + label*
df = pd.read_csv(r'../data/malaya/semisupervised-bert-xlnet.csv')
combined_df = pd.concat([combined_df, df[['text', 'label']].rename(columns={'label': 'sentiment'})])

# semisupervised-bert-xlnet: text + label*
df = pd.read_csv(r'../data/malaya/semisupervised-politics-bert-xlnet.csv')
combined_df = pd.concat([combined_df, df[['text', 'label']].rename(columns={'label': 'sentiment'})])

# supervised-data: text + sentiment* 
df = pd.read_csv(r'../data/malaya/supervised-data.csv', sep='\t')
combined_df = pd.concat([combined_df, df[['text', 'sentiment']]])

# supervised-data-politics: text + sentiment* 
df = pd.read_csv(r'../data/malaya/supervised-data-politics.csv', sep='\t')
combined_df = pd.concat([combined_df, df[['text', 'sentiment']]])

# supervised-data-politics: text + sentiment* 
df = pd.read_csv(r'../data/malaya/manglish.csv', sep='\t')
df['sentiment'] = df['sentiment'].apply(lambda x: x.capitalize())
combined_df = pd.concat([combined_df, df[['text', 'sentiment']]])

# twitter: text + sentiment* 
df = pd.read_csv(r'../data/scrapping/twitter.csv', sep='\t')
df['sentiment'] = df['sentiment'].apply(lambda x: x.capitalize())
combined_df = pd.concat([combined_df, df[['text', 'sentiment']]])

combined_df = combined_df.reset_index()[['text', 'sentiment']]
combined_df
# Out:
#                                                      text sentiment
# 0       Lebih-lebih lagi dengan  kemudahan internet da...  Negative
# 1       boleh memberi teguran kepada parti tetapi perl...  Positive
# 2       Adalah membingungkan mengapa masyarakat Cina b...  Negative
# 3       Kami menurunkan defisit daripada 6.7 peratus p...  Positive
# 4             Ini masalahnya. Bukan rakyat, tetapi sistem  Negative
# ...                                                   ...       ...
# 543662           Boxi in Alliance : 🤡\nBoxi in Liquid : 🗿  Positive
# 543663                          Liquid tolong pause sat 🤣   Neutral
# 543664  The last time dine-in here was on the day @Nig...  Positive
# 543665         Meriah lower bracket liquid pun jatuh huhu  Negative
# 543666               sad cant see og liquid rematch again   Neutral
#
# [543667 rows x 2 columns]

# %% [markdown]
# # 2. Data preprocessing

# %% [markdown]
# ## 2.1 Data Cleaning

# %%
from unidecode import unidecode
import string
import re

punctuation = '‘’“”!$%&\()*+,./:;<=>?[\\]^_`{|}~•@…'

def clean_text(text):
    # convert characters to ascii
    text = unidecode(text)
    
    # remove words that is hashtags, mentions and links
    text = re.sub(r'^([@#]|http|https)[^\s]*', '', text)
    
    # remove punctuation
    text = text.translate(text.maketrans('', '', punctuation))
    
    # remove next line     
    text = re.sub('\n', '', text)
    
    # lowercasing text
    text = text.lower()
    
    # stripping text
    text = text.strip()
    
    # remove words containing numbers
    text = re.sub('\w*\d\w*', '', text)
    
    return text
    
combined_df['text'] = combined_df['text'].apply(lambda x: clean_text(x))
combined_df
# Out:
#                                                      text sentiment
# 0       lebih-lebih lagi dengan  kemudahan internet da...  Negative
# 1       boleh memberi teguran kepada parti tetapi perl...  Positive
# 2       adalah membingungkan mengapa masyarakat cina b...  Negative
# 3       kami menurunkan defisit daripada  peratus pada...  Positive
# 4               ini masalahnya bukan rakyat tetapi sistem  Negative
# ...                                                   ...       ...
# 543662                   boxi in alliance  boxi in liquid  Positive
# 543663                            liquid tolong pause sat   Neutral
# 543664  the last time dine-in here was on the day nigm...  Positive
# 543665         meriah lower bracket liquid pun jatuh huhu  Negative
# 543666               sad cant see og liquid rematch again   Neutral
#
# [543667 rows x 2 columns]

# %% [markdown]
# ## 2.2 Normalise short-form words

# %%
malaya_sf = pd.read_csv(r'../normalise/malaya.csv')
cilisos_sf = pd.read_csv(r'../normalise/cilisos.csv', encoding='ISO-8859-1')

combined_sf = {x[0]: x[1] for x in malaya_sf.values.tolist() + cilisos_sf.values.tolist()}

def normalise_text(text):
    return ' '.join([combined_sf[x] if x in combined_sf.keys() else x for x in text.split()])

combined_df['text'] = combined_df['text'].apply(lambda x: normalise_text(x))
combined_df
# Out:
#                                                      text sentiment
# 0       lebih-lebih lagi dengan kemudahan internet dan...  Negative
# 1       boleh memberi teguran kepada parti tetapi perl...  Positive
# 2       adalah membingungkan mengapa masyarakat cina b...  Negative
# 3       kami menurunkan defisit daripada peratus pada ...  Positive
# 4               ini masalahnya bukan rakyat tetapi sistem  Negative
# ...                                                   ...       ...
# 543662                    boxi in alliance boxi in liquid  Positive
# 543663                          liquid tolong pause sabtu   Neutral
# 543664  the akhir masa dine-in here was on the hari ni...  Positive
# 543665         meriah lower bracket liquid pun jatuh huhu  Negative
# 543666          sad tak boleh sih og liquid rematch again   Neutral
#
# [543667 rows x 2 columns]

# %% [markdown]
# ## 2.3 Randomly sample datasets

# %%
combined_df_all = combined_df

# %%
combined_df = combined_df_all.sample(n=50000).reset_index()[['text', 'sentiment']]
combined_df
# Out:
#                                                     text sentiment
# 0                              looks like scum kepada me  Positive
# 1      perhatian status aras air semasa di sarawak mi...   Neutral
# 2                     change the heart of china kemudian  Negative
# 3              can rebate further dengan gc and shopback  Positive
# 4                           aku baru habis tengok padman   Neutral
# ...                                                  ...       ...
# 49995                          haha yeah that's the plan  Negative
# 49996                and only available untuk porting in  Positive
# 49997  macam ini sudah pun tetapi ahli politik still ...  Negative
# 49998             dengan kemudian ish they laugh pada us  Negative
# 49999                               baik luck pearthin #  Positive
#
# [50000 rows x 2 columns]

# %% [markdown]
# # 3. Get feature and targets

# %% [markdown]
# ## 3.1 Load tokenizer

# %%
import torch
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained(model_name)

# %% [markdown]
# ## 3.2 Testing datasets and modeling

# %%
# text = "She sells"
# # if we tokenize it, this becomes:
# encoding = tokenizer(text, return_tensors="pt")
# encoding['language_ids'] = torch.tensor([[0, 1, 1, 0]])

# print(encoding['input_ids'])

# for input_id in encoding['input_ids']:
#     print(tokenizer.decode(input_id))

# %%
# # tokenize the text feature 
# tokenized_feature_raw = tokenizer.batch_encode_plus(
#     # Sentences to encode
#     combined_df.text.values.tolist(), 
#     # Add '[CLS]' and '[SEP]'
#     add_special_tokens = True
# )

# # collect tokenized sentence length
# token_sentence_length = [len(x) for x in tokenized_feature_raw['input_ids']]
# print('max: ', max(token_sentence_length))
# print('min: ', min(token_sentence_length))

# # plot the distribution
# import matplotlib.pyplot as plt
# plt.figure(figsize=(20, 8))
# plt.hist(token_sentence_length, rwidth = 0.9)
# plt.xlabel('Sequence Length', fontsize = 18)
# plt.ylabel('# of Samples', fontsize = 18)
# plt.xticks(fontsize = 14)
# plt.yticks(fontsize = 14)

# %% [markdown]
# ## 3.3 Prepare features and target

# %%
# identify features and target
features = combined_df.text.values.tolist()
target = combined_df.sentiment.values.tolist()

print(features[:5])
# Out:
# ['looks like scum kepada me', 'perhatian status aras air semasa di sarawak miri marudi aras air sungai adalah iait', 'change the heart of china kemudian', 'can rebate further dengan gc and shopback', 'aku baru habis tengok padman']

# %%
# tokenize features 
MAX_LEN = 128
tokenized_feature = tokenizer.batch_encode_plus(
    # Sentences to encode
    features, 
    # Add '[CLS]' and '[SEP]'
    add_special_tokens = True,
    # Add empty tokens if len(text)<MAX_LEN
    padding = 'max_length',
    # Truncate all sentences to max length
    truncation=True,
    # Set the maximum length
    max_length = MAX_LEN, 
    # Return attention mask
    return_attention_mask = True,
    # Return pytorch tensors
    return_tensors = 'pt'       
)

# %% [markdown]
# ## 3.4 Add language embeddings

# %%
special_token_list = set(['[CLS]', '[SEP]', '[PAD]', '[UNK]'])

lang_id2num = { 'special_token': 0, 'english': 1, 'malay': 2, 'other': 3 }
lang_num2id = {v:k for k,v in lang_id2num.items()}

def detect_lang(text):
    if text in special_token_list:
        return 'special_token'
    elif detect_malay(text):
        return 'malay'
    elif detect_english(text):
        return 'english'
    else:
        return 'other'

# %%
# detect language function is on section 1

def get_lang_tokens(input_tokens):
    decoded_tokens = [x.replace(' ', '') for x in reversed(tokenizer.batch_decode(input_tokens))]
    language_ids = []
    
    full_sentence = ''
    token_count = 0
    for token in decoded_tokens:
        if '##' in token:
            full_sentence = token[2:] + full_sentence
            token_count += 1
            continue

        full_sentence = token + full_sentence
        token_count += 1
        lang_token = lang_id2num[detect_lang(full_sentence)]
        for _ in range(token_count):
            language_ids.append(lang_token)
        
        full_sentence = ''
        token_count = 0
        
    return language_ids

# %%
# { 'special_token': 0, 'english': 1, 'malay': 2, 'other': 3 }

language_ids = []
for input_id in tokenized_feature['input_ids']:
    input_tokens = input_id.tolist()
    
    language_ids.append(get_lang_tokens(input_tokens))

language_ids = torch.tensor(language_ids)

tokenized_feature['language_ids'] = language_ids

tokenized_feature['language_ids']
# Out:
# tensor([[0, 0, 0,  ..., 2, 2, 0],
#         [0, 0, 0,  ..., 2, 2, 0],
#         [0, 0, 0,  ..., 2, 1, 0],
#         ...,
#         [0, 0, 0,  ..., 2, 2, 0],
#         [0, 0, 0,  ..., 2, 2, 0],
#         [0, 0, 0,  ..., 2, 2, 0]])

# %% [markdown]
# ## 3.5 Numeric target

# %%
# # install sklearn 
# !pip install sklearn

# convert label into numeric 
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(target)
target_num = le.transform(target)

print(target_num[:20])
# Out:
# [2 1 0 2 1 1 0 0 2 1 0 0 2 1 1 1 1 2 1 1]

# %% [markdown]
# ## 3.6 Pickle files

# %%
import pickle
pickle_path = '../pickle/bert+li_feature_target.pickle'

feature_target = [tokenized_feature, target, target_num]

with open(pickle_path, 'wb') as fp:
    pickle.dump(feature_target, fp)

# %% [markdown]
# # 4 Prepare train and validation set

# %%
import pickle
pickle_path = '../pickle/bert+li_feature_target.pickle'

with open(pickle_path, 'rb') as fp:
    tokenized_feature, target, target_num = pickle.load(fp)

# %%
# Use 80% for training and 20% for validation
from sklearn.model_selection import train_test_split

train_inputs, validation_inputs, train_labels, validation_labels, train_masks, validation_masks, train_langs, validation_langs = train_test_split(tokenized_feature['input_ids'], 
                                                                                                                                                  target_num,
                                                                                                                                                  tokenized_feature['attention_mask'],
                                                                                                                                                  tokenized_feature['language_ids'],
                                                                                                                                                  random_state=2018,
                                                                                                                                                  test_size=0.2,
                                                                                                                                                  stratify=target)

# %%
from torch.utils.data import TensorDataset, RandomSampler, DataLoader, SequentialSampler

# define batch_size
batch_size = 16
# Create the DataLoader for our training set
train_data = TensorDataset(train_inputs, train_masks, train_langs, torch.tensor(train_labels))
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)
# Create the DataLoader for our test set
validation_data = TensorDataset(validation_inputs, validation_masks, validation_langs, torch.tensor(validation_labels))
validation_sampler = SequentialSampler(validation_data)
validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=batch_size)

# %% [markdown]
# # 5 Settings up BERT Model

# %%
# BertForSequenceClassification
from transformers import AdamW, get_linear_schedule_with_warmup
from modeling_bert import BertForSequenceClassification

model = BertForSequenceClassification.from_pretrained(
    model_name, 
    # Specify number of classes
    num_labels = len(set(target)), 
    # Whether the model returns attentions weights
    output_attentions = False,
    # Whether the model returns all hidden-states 
    output_hidden_states = False
)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'bert.embeddings.language_embeddings.weight', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained(model_name)

# Because we add two words [‘covid’, ‘coronavirus’] into the vocabulary
# we will need to resize the token to make sure the model pick it up as whole words.

# Receive the full size of the new word
model.resize_token_embeddings(len(tokenizer))

# Optimizer & Learning Rate Scheduler
optimizer = AdamW(model.parameters(),
                  lr = 2e-5, 
                  eps = 1e-8 
                )
# Out:
# C:\Users\cafer\anaconda3\lib\site-packages\transformers\optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Number of training epochs
epochs = 4
# Total number of training steps is number of batches * number of epochs.
total_steps = len(train_dataloader) * epochs
# Create the learning rate scheduler
scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps = 0,
                                            num_training_steps = total_steps)

# %%
# use cuda if existing
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

model.to(device)

# %%
# Training
import time
# Store the average loss after each epoch 
loss_values = []
# number of total steps for each epoch
print('total steps per epoch: ',  len(train_dataloader) / batch_size)
# looping over epochs
for epoch_i in range(0, epochs):
    
    print('training on epoch: ', epoch_i)
    # set start time 
    t0 = time.time()
    # reset total loss
    total_loss = 0
    # model in training 
    model.train()
    # loop through batch 
    for step, batch in enumerate(train_dataloader):
        # Progress update every 50 step 
        if step % 50 == 0 and not step == 0:
            print('training on step: ', step)
            print('total time used is: {0:.2f} s'.format(time.time() - t0))
        # load data from dataloader 
        b_input_ids = batch[0].to(device).long()
        b_input_mask = batch[1].to(device).long()
        b_input_langs = batch[2].to(device).long()
        b_labels = batch[3].to(device).long()
        # clear any previously calculated gradients 
        model.zero_grad()
        # get outputs
        outputs = model(input_ids=b_input_ids,
                        token_type_ids=None,
                        attention_mask=b_input_mask,
                        language_ids=b_input_langs,
                        labels=b_labels)
        # get loss
        loss = outputs[0]
        # total loss
        total_loss += loss.item()
        # clip the norm of the gradients to 1.0.
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        # update optimizer
        optimizer.step()
        # update learning rate 
        scheduler.step()
    # Calculate the average loss over the training data.
    avg_train_loss = total_loss / len(train_dataloader)
    # Store the loss value for plotting the learning curve.
    loss_values.append(avg_train_loss)
    print("average training loss: {0:.2f}".format(avg_train_loss))
# Out:
# total steps per epoch:  156.25
# training on epoch:  0
# training on step:  50
# total time used is: 182.94 s
# training on step:  100
# total time used is: 366.08 s
# training on step:  150
# total time used is: 546.91 s
# training on step:  200
# total time used is: 730.50 s
# training on step:  250
# total time used is: 909.16 s
# training on step:  300
# total time used is: 1090.37 s
# training on step:  350
# total time used is: 1275.06 s
# training on step:  400
# total time used is: 1459.23 s
# training on step:  450
# total time used is: 1646.31 s
# training on step:  500
# total time used is: 1833.20 s
# training on step:  550
# total time used is: 2022.92 s
# training on step:  600
# total time used is: 2214.73 s
# training on step:  650
# total time used is: 2407.26 s
# training on step:  700
# total time used is: 2597.97 s
# training on step:  750
# total time used is: 2802.59 s
# training on step:  800
# total time used is: 3018.60 s
# training on step:  850
# total time used is: 3231.72 s
# training on step:  900
# total time used is: 3441.49 s
# training on step:  950
# total time used is: 3657.58 s
# training on step:  1000
# total time used is: 3843.54 s
# training on step:  1050
# total time used is: 4030.41 s
# training on step:  1100
# total time used is: 4217.27 s
# training on step:  1150
# total time used is: 4408.67 s
# training on step:  1200
# total time used is: 4609.15 s
# training on step:  1250
# total time used is: 4816.35 s
# training on step:  1300
# total time used is: 5018.48 s
# training on step:  1350
# total time used is: 5209.85 s
# training on step:  1400
# total time used is: 5402.89 s
# training on step:  1450
# total time used is: 5594.64 s
# training on step:  1500
# total time used is: 5785.69 s
# training on step:  1550
# total time used is: 5980.03 s
# training on step:  1600
# total time used is: 6174.53 s
# training on step:  1650
# total time used is: 6368.11 s
# training on step:  1700
# total time used is: 6566.30 s
# training on step:  1750
# total time used is: 6760.79 s
# training on step:  1800
# total time used is: 6954.53 s
# training on step:  1850
# total time used is: 7147.52 s
# training on step:  1900
# total time used is: 7339.46 s
# training on step:  1950
# total time used is: 7533.18 s
# training on step:  2000
# total time used is: 7725.99 s
# training on step:  2050
# total time used is: 7917.56 s
# training on step:  2100
# total time used is: 8111.41 s
# training on step:  2150
# total time used is: 8303.78 s
# training on step:  2200
# total time used is: 8495.93 s
# training on step:  2250
# total time used is: 8689.98 s
# training on step:  2300
# total time used is: 8884.14 s
# training on step:  2350
# total time used is: 9077.96 s
# training on step:  2400
# total time used is: 9272.04 s
# training on step:  2450
# total time used is: 9468.36 s
# average training loss: 1.11
# training on epoch:  1
# training on step:  50
# total time used is: 197.16 s
# training on step:  100
# total time used is: 393.67 s
# training on step:  150
# total time used is: 591.80 s
# training on step:  200
# total time used is: 791.65 s
# training on step:  250
# total time used is: 989.53 s
# training on step:  300
# total time used is: 1191.08 s
# training on step:  350
# total time used is: 1392.47 s
# training on step:  400
# total time used is: 1591.89 s
# training on step:  450
# total time used is: 1788.10 s
# training on step:  500
# total time used is: 1986.39 s
# training on step:  550
# total time used is: 2185.36 s
# training on step:  600
# total time used is: 2384.98 s
# training on step:  650
# total time used is: 2595.53 s
# training on step:  700
# total time used is: 2812.12 s
# training on step:  750
# total time used is: 3055.46 s
# training on step:  800
# total time used is: 3286.92 s
# training on step:  850
# total time used is: 3507.45 s
# training on step:  900
# total time used is: 3722.99 s
# training on step:  950
# total time used is: 3937.36 s
# training on step:  1000
# total time used is: 4152.43 s
# training on step:  1050
# total time used is: 4379.78 s
# training on step:  1100
# total time used is: 4577.37 s
# training on step:  1150
# total time used is: 4768.34 s
# training on step:  1200
# total time used is: 4963.22 s
# training on step:  1250
# total time used is: 5165.99 s
# training on step:  1300
# total time used is: 5358.33 s
# training on step:  1350
# total time used is: 5522.36 s
# training on step:  1400
# total time used is: 5692.03 s
# training on step:  1450
# total time used is: 5869.73 s
# training on step:  1500
# total time used is: 6044.54 s
# training on step:  1550
# total time used is: 6215.16 s
# training on step:  1600
# total time used is: 6386.17 s
# training on step:  1650
# total time used is: 6558.22 s
# training on step:  1700
# total time used is: 6730.40 s
# training on step:  1750
# total time used is: 6902.69 s
# training on step:  1800
# total time used is: 7074.22 s
# training on step:  1850
# total time used is: 7249.55 s
# training on step:  1900
# total time used is: 7423.83 s
# training on step:  1950
# total time used is: 7596.58 s
# training on step:  2000
# total time used is: 7769.50 s
# training on step:  2050
# total time used is: 7942.12 s
# training on step:  2100
# total time used is: 8114.59 s
# training on step:  2150
# total time used is: 8283.76 s
# training on step:  2200
# total time used is: 8455.76 s
# training on step:  2250
# total time used is: 8628.57 s
# training on step:  2300
# total time used is: 8800.96 s
# training on step:  2350
# total time used is: 8974.51 s
# training on step:  2400
# total time used is: 9149.78 s
# training on step:  2450
# total time used is: 9316.47 s
# average training loss: 1.11
# training on epoch:  2
# training on step:  50
# total time used is: 174.00 s
# training on step:  100
# total time used is: 350.63 s
# training on step:  150
# total time used is: 524.00 s
# training on step:  200
# total time used is: 696.27 s
# training on step:  250
# total time used is: 870.20 s
# training on step:  300
# total time used is: 1043.90 s
# training on step:  350
# total time used is: 1225.70 s
# training on step:  400
# total time used is: 1399.36 s
# training on step:  450
# total time used is: 1575.07 s
# training on step:  500
# total time used is: 1748.91 s
# training on step:  550
# total time used is: 1922.32 s
# training on step:  600
# total time used is: 2094.80 s
# training on step:  650
# total time used is: 2268.29 s
# training on step:  700
# total time used is: 2441.68 s
# training on step:  750
# total time used is: 2615.01 s
# training on step:  800
# total time used is: 2788.69 s
# training on step:  850
# total time used is: 2962.03 s
# training on step:  900
# total time used is: 3135.31 s
# training on step:  950
# total time used is: 3308.66 s
# training on step:  1000
# total time used is: 3481.72 s
# training on step:  1050
# total time used is: 3657.31 s
# training on step:  1100
# total time used is: 3831.44 s
# training on step:  1150
# total time used is: 4003.64 s
# training on step:  1200
# total time used is: 4179.78 s
# training on step:  1250
# total time used is: 4352.56 s
# training on step:  1300
# total time used is: 4526.40 s
# training on step:  1350
# total time used is: 4700.07 s
# training on step:  1400
# total time used is: 4874.00 s
# training on step:  1450
# total time used is: 5046.33 s
# training on step:  1500
# total time used is: 5220.41 s
# training on step:  1550
# total time used is: 5394.78 s
# training on step:  1600
# total time used is: 5569.36 s
# training on step:  1650
# total time used is: 5743.83 s
# training on step:  1700
# total time used is: 5919.13 s
# training on step:  1750
# total time used is: 6093.35 s
# training on step:  1800
# total time used is: 6267.17 s
# training on step:  1850
# total time used is: 6441.68 s
# training on step:  1900
# total time used is: 6615.15 s
# training on step:  1950
# total time used is: 6789.03 s
# training on step:  2000
# total time used is: 6962.24 s
# training on step:  2050
# total time used is: 7135.30 s
# training on step:  2100
# total time used is: 7309.04 s
# training on step:  2150
# total time used is: 7483.96 s
# training on step:  2200
# total time used is: 7657.35 s
# training on step:  2250
# total time used is: 7829.39 s
# training on step:  2300
# total time used is: 8004.32 s
# training on step:  2350
# total time used is: 8176.45 s
# training on step:  2400
# total time used is: 8349.29 s
# training on step:  2450
# total time used is: 8522.65 s
# average training loss: 1.11
# training on epoch:  3
# training on step:  50
# total time used is: 171.94 s
# training on step:  100
# total time used is: 345.72 s
# training on step:  150
# total time used is: 519.29 s
# training on step:  200
# total time used is: 693.40 s
# training on step:  250
# total time used is: 866.47 s
# training on step:  300
# total time used is: 1039.03 s
# training on step:  350
# total time used is: 1212.57 s
# training on step:  400
# total time used is: 1385.35 s
# training on step:  450
# total time used is: 1558.86 s
# training on step:  500
# total time used is: 1733.84 s
# training on step:  550
# total time used is: 1904.97 s
# training on step:  600
# total time used is: 2079.67 s
# training on step:  650
# total time used is: 2253.95 s
# training on step:  700
# total time used is: 2423.95 s
# training on step:  750
# total time used is: 2593.69 s
# training on step:  800
# total time used is: 2769.38 s
# training on step:  850
# total time used is: 2943.04 s
# training on step:  900
# total time used is: 3113.69 s
# training on step:  950
# total time used is: 3288.52 s
# training on step:  1000
# total time used is: 3463.08 s
# training on step:  1050
# total time used is: 3638.95 s
# training on step:  1100
# total time used is: 3813.23 s
# training on step:  1150
# total time used is: 3984.98 s
# training on step:  1200
# total time used is: 4158.05 s
# training on step:  1250
# total time used is: 4331.21 s
# training on step:  1300
# total time used is: 4505.73 s
# training on step:  1350
# total time used is: 4677.83 s
# training on step:  1400
# total time used is: 4854.68 s
# training on step:  1450
# total time used is: 5026.46 s
# training on step:  1500
# total time used is: 5201.42 s
# training on step:  1550
# total time used is: 5389.27 s
# training on step:  1600
# total time used is: 5571.22 s
# training on step:  1650
# total time used is: 5762.99 s
# training on step:  1700
# total time used is: 5951.11 s
# training on step:  1750
# total time used is: 6139.05 s
# training on step:  1800
# total time used is: 6319.34 s
# training on step:  1850
# total time used is: 6501.15 s
# training on step:  1900
# total time used is: 6686.72 s
# training on step:  1950
# total time used is: 6861.75 s
# training on step:  2000
# total time used is: 7037.82 s
# training on step:  2050
# total time used is: 7213.97 s
# training on step:  2100
# total time used is: 7390.37 s
# training on step:  2150
# total time used is: 7567.67 s
# training on step:  2200
# total time used is: 7743.61 s
# training on step:  2250
# total time used is: 7935.39 s
# training on step:  2300
# total time used is: 8115.20 s
# training on step:  2350
# total time used is: 8294.66 s
# training on step:  2400
# total time used is: 8473.57 s
# training on step:  2450
# total time used is: 8650.05 s
# average training loss: 1.11

# %%
# !mkdir -p ..\saved_model\bert+li

torch.save(model, '../saved_model/bert+li/bert+li_sentiment')

# %%
# Test
import numpy as np
t0 = time.time()
# model in validation mode
model.eval()
# save prediction
predictions,true_labels =[],[]
# evaluate data for one epoch
for batch in validation_dataloader:
    # Add batch to GPU
    batch = tuple(t.to(device) for t in batch)
    # Unpack the inputs from our dataloader
    b_input_ids, b_input_mask, b_input_langs, b_labels = batch
    # validation
    with torch.no_grad():
        outputs = model(input_ids=b_input_ids.long(),
                        token_type_ids=None,
                        attention_mask=b_input_mask.long(),
                        language_ids=b_input_langs.long())
    # get output
    logits = outputs[0]
    # move logits and labels to CPU
    logits = logits.detach().cpu().numpy()
    label_ids = b_labels.to('cpu').numpy()
    final_prediction = np.argmax(logits, axis=-1).flatten()
    predictions.append(final_prediction)
    true_labels.append(label_ids)
    
print('total time used is: {0:.2f} s'.format(time.time() - t0))
# Out:
# total time used is: 4196.79 s

# %%
import pickle
# !mkdir -p ..\saved_model\bert+li

with open('../saved_model/bert+li/bert+li_sentiment_predictions', 'wb') as fp:
    pickle.dump([predictions, true_labels], fp)
# Out:
# A subdirectory or file -p already exists.
# Error occurred while processing: -p.
# A subdirectory or file ..\saved_model\bert+li already exists.
# Error occurred while processing: ..\saved_model\bert+li.

# %% [markdown]
# # 6 Confusion Matrix

# %%
# convert numeric label to string
final_prediction_list = le.inverse_transform(np.concatenate(predictions))
final_truelabel_list = le.inverse_transform(np.concatenate(true_labels))

# %%
from sklearn.metrics import confusion_matrix, classification_report
cr = classification_report(final_truelabel_list, 
                           final_prediction_list, 
                           output_dict=False)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.27      0.03      0.05      3438
#      Neutral       0.14      0.05      0.07      2738
#     Positive       0.38      0.87      0.53      3824
#
#     accuracy                           0.36     10000
#    macro avg       0.26      0.31      0.22     10000
# weighted avg       0.28      0.36      0.24     10000

# %%
# # install seaborn
# !pip install seaborn

# print cm heatmap
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# return class label
class_label = np.unique(final_truelabel_list)
# get confusion matrix 
cm = confusion_matrix(final_truelabel_list,
                      final_prediction_list)
# covert it to dataframe for plotting
cm_df = pd.DataFrame(cm, 
                     index = class_label, 
                     columns = class_label)
# plot it 
plt.figure(figsize = (10,8))
g = sns.heatmap(cm_df, cmap = 'hot_r', annot=True, fmt='g')
g.xaxis.set_ticks_position("top")
g.tick_params(axis='x', rotation=90)
g.set_xlabel("True Sentiment Label")
g.set_ylabel("Predicted Sentiment Label")
# Out:
# Text(95.72222222222221, 0.5, 'Predicted Sentiment Label')
